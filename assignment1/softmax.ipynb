# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.329027
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.281137 analytic: 0.281137, relative error: 2.152480e-07
# numerical: 1.419562 analytic: 1.419562, relative error: 3.195600e-08
# numerical: -2.068278 analytic: -2.068278, relative error: 2.171747e-09
# numerical: -2.446599 analytic: -2.446599, relative error: 2.580996e-08
# numerical: 1.570270 analytic: 1.570270, relative error: 4.004818e-08
# numerical: 2.188350 analytic: 2.188350, relative error: 1.188611e-08
# numerical: -0.621986 analytic: -0.621986, relative error: 1.483994e-08
# numerical: -0.623299 analytic: -0.623299, relative error: 1.597517e-09
# numerical: 2.471243 analytic: 2.471243, relative error: 4.152145e-08
# numerical: 1.807656 analytic: 1.807656, relative error: 3.165051e-08
# numerical: 0.588539 analytic: 0.588539, relative error: 2.690640e-08
# numerical: 0.001195 analytic: 0.001195, relative error: 3.721869e-05
# numerical: 0.541489 analytic: 0.541489, relative error: 3.403200e-09
# numerical: -0.506472 analytic: -0.506473, relative error: 2.818031e-08
# numerical: -2.640303 analytic: -2.640303, relative error: 2.507147e-08
# numerical: 0.804440 analytic: 0.804440, relative error: 6.822793e-08
# numerical: -0.619968 analytic: -0.619968, relative error: 1.951100e-08
# numerical: -4.496426 analytic: -4.496427, relative error: 1.890266e-08
# numerical: 1.897979 analytic: 1.897979, relative error: 1.787332e-08
# numerical: 2.866477 analytic: 2.866477, relative error: 4.071807e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print(loss_vectorized.shape)
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))
# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.329027e+00 computed in 0.103006s
# ()
# vectorized loss: 2.329027e+00 computed in 0.004008s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-8,1e-7, 5e-7]
regularization_strengths = [1e3,1.5e4,2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        loss_hist = softmax.train(X_train, y_train, learning_rate=lr, reg=reg,
                          num_iters=3000, verbose=True)
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        val_accuracy = np.mean(y_val == y_val_pred)
        results[(lr,reg)] = (np.mean(y_train == y_train_pred), val_accuracy)

        if best_val < val_accuracy:
            best_val = val_accuracy
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 3000: loss 36.181959
# iteration 100 / 3000: loss 36.096079
# iteration 200 / 3000: loss 35.131657
# iteration 300 / 3000: loss 34.905354
# iteration 400 / 3000: loss 34.685615
# iteration 500 / 3000: loss 34.617822
# iteration 600 / 3000: loss 33.816850
# iteration 700 / 3000: loss 33.688462
# iteration 800 / 3000: loss 33.879680
# iteration 900 / 3000: loss 33.340244
# iteration 1000 / 3000: loss 33.055511
# iteration 1100 / 3000: loss 33.205731
# iteration 1200 / 3000: loss 33.057121
# iteration 1300 / 3000: loss 32.634673
# iteration 1400 / 3000: loss 32.590448
# iteration 1500 / 3000: loss 32.474319
# iteration 1600 / 3000: loss 32.099437
# iteration 1700 / 3000: loss 31.905756
# iteration 1800 / 3000: loss 31.681153
# iteration 1900 / 3000: loss 31.929857
# iteration 2000 / 3000: loss 31.542290
# iteration 2100 / 3000: loss 31.369462
# iteration 2200 / 3000: loss 31.389117
# iteration 2300 / 3000: loss 31.256406
# iteration 2400 / 3000: loss 30.972454
# iteration 2500 / 3000: loss 30.905666
# iteration 2600 / 3000: loss 30.737111
# iteration 2700 / 3000: loss 30.566936
# iteration 2800 / 3000: loss 30.648713
# iteration 2900 / 3000: loss 30.252831
# iteration 0 / 3000: loss 468.773838
# iteration 100 / 3000: loss 441.463278
# iteration 200 / 3000: loss 415.230687
# iteration 300 / 3000: loss 391.202412
# iteration 400 / 3000: loss 367.838501
# iteration 500 / 3000: loss 346.612356
# iteration 600 / 3000: loss 326.664482
# iteration 700 / 3000: loss 307.365109
# iteration 800 / 3000: loss 289.262749
# iteration 900 / 3000: loss 272.594855
# iteration 1000 / 3000: loss 256.755901
# iteration 1100 / 3000: loss 241.826402
# iteration 1200 / 3000: loss 227.593139
# iteration 1300 / 3000: loss 214.686968
# iteration 1400 / 3000: loss 202.236276
# iteration 1500 / 3000: loss 190.544950
# iteration 1600 / 3000: loss 179.394721
# iteration 1700 / 3000: loss 169.154820
# iteration 1800 / 3000: loss 159.255323
# iteration 1900 / 3000: loss 150.154463
# iteration 2000 / 3000: loss 141.408698
# iteration 2100 / 3000: loss 133.224892
# iteration 2200 / 3000: loss 125.528661
# iteration 2300 / 3000: loss 118.312258
# iteration 2400 / 3000: loss 111.461366
# iteration 2500 / 3000: loss 105.202846
# iteration 2600 / 3000: loss 99.141202
# iteration 2700 / 3000: loss 93.569738
# iteration 2800 / 3000: loss 88.098703
# iteration 2900 / 3000: loss 83.118305
# iteration 0 / 3000: loss 775.231612
# iteration 100 / 3000: loss 701.493849
# iteration 200 / 3000: loss 634.864479
# iteration 300 / 3000: loss 574.328221
# iteration 400 / 3000: loss 519.534722
# iteration 500 / 3000: loss 470.142228
# iteration 600 / 3000: loss 425.375784
# iteration 700 / 3000: loss 384.882140
# iteration 800 / 3000: loss 348.545463
# iteration 900 / 3000: loss 315.348046
# iteration 1000 / 3000: loss 285.284488
# iteration 1100 / 3000: loss 258.233615
# iteration 1200 / 3000: loss 233.881625
# iteration 1300 / 3000: loss 211.636897
# iteration 1400 / 3000: loss 191.540691
# iteration 1500 / 3000: loss 173.596580
# iteration 1600 / 3000: loss 157.317934
# iteration 1700 / 3000: loss 142.445372
# iteration 1800 / 3000: loss 128.997715
# iteration 1900 / 3000: loss 116.989596
# iteration 2000 / 3000: loss 105.944001
# iteration 2100 / 3000: loss 96.032920
# iteration 2200 / 3000: loss 87.090061
# iteration 2300 / 3000: loss 78.977658
# iteration 2400 / 3000: loss 71.660535
# iteration 2500 / 3000: loss 65.060648
# iteration 2600 / 3000: loss 58.988543
# iteration 2700 / 3000: loss 53.641288
# iteration 2800 / 3000: loss 48.663078
# iteration 2900 / 3000: loss 44.106639
# iteration 0 / 3000: loss 1522.169940
# iteration 100 / 3000: loss 1246.408735
# iteration 200 / 3000: loss 1020.110789
# iteration 300 / 3000: loss 835.053510
# iteration 400 / 3000: loss 683.872462
# iteration 500 / 3000: loss 559.856515
# iteration 600 / 3000: loss 458.446798
# iteration 700 / 3000: loss 375.435196
# iteration 800 / 3000: loss 307.758961
# iteration 900 / 3000: loss 252.217722
# iteration 1000 / 3000: loss 206.817442
# iteration 1100 / 3000: loss 169.691561
# iteration 1200 / 3000: loss 139.260356
# iteration 1300 / 3000: loss 114.320015
# iteration 1400 / 3000: loss 93.926820
# iteration 1500 / 3000: loss 77.278896
# iteration 1600 / 3000: loss 63.613550
# iteration 1700 / 3000: loss 52.391343
# iteration 1800 / 3000: loss 43.389885
# iteration 1900 / 3000: loss 35.876246
# iteration 2000 / 3000: loss 29.702314
# iteration 2100 / 3000: loss 24.689464
# iteration 2200 / 3000: loss 20.635311
# iteration 2300 / 3000: loss 17.207316
# iteration 2400 / 3000: loss 14.493888
# iteration 2500 / 3000: loss 12.226235
# iteration 2600 / 3000: loss 10.418394
# iteration 2700 / 3000: loss 8.926850
# iteration 2800 / 3000: loss 7.675051
# iteration 2900 / 3000: loss 6.681244
# iteration 0 / 3000: loss 35.709493
# iteration 100 / 3000: loss 32.920402
# iteration 200 / 3000: loss 31.372359
# iteration 300 / 3000: loss 29.753166
# iteration 400 / 3000: loss 28.973597
# iteration 500 / 3000: loss 27.373010
# iteration 600 / 3000: loss 26.482224
# iteration 700 / 3000: loss 25.410844
# iteration 800 / 3000: loss 24.367886
# iteration 900 / 3000: loss 23.382610
# iteration 1000 / 3000: loss 22.531301
# iteration 1100 / 3000: loss 21.855439
# iteration 1200 / 3000: loss 20.859225
# iteration 1300 / 3000: loss 20.119289
# iteration 1400 / 3000: loss 19.306584
# iteration 1500 / 3000: loss 18.606207
# iteration 1600 / 3000: loss 17.895451
# iteration 1700 / 3000: loss 17.324346
# iteration 1800 / 3000: loss 16.733504
# iteration 1900 / 3000: loss 16.088338
# iteration 2000 / 3000: loss 15.400038
# iteration 2100 / 3000: loss 14.909629
# iteration 2200 / 3000: loss 14.312549
# iteration 2300 / 3000: loss 13.851533
# iteration 2400 / 3000: loss 13.512331
# iteration 2500 / 3000: loss 12.981821
# iteration 2600 / 3000: loss 12.414646
# iteration 2700 / 3000: loss 11.997970
# iteration 2800 / 3000: loss 11.562253
# iteration 2900 / 3000: loss 11.199744
# iteration 0 / 3000: loss 469.939628
# iteration 100 / 3000: loss 256.922767
# iteration 200 / 3000: loss 141.463408
# iteration 300 / 3000: loss 78.299543
# iteration 400 / 3000: loss 43.776139
# iteration 500 / 3000: loss 24.838294
# iteration 600 / 3000: loss 14.520353
# iteration 700 / 3000: loss 8.840454
# iteration 800 / 3000: loss 5.769689
# iteration 900 / 3000: loss 4.050045
# iteration 1000 / 3000: loss 3.201863
# iteration 1100 / 3000: loss 2.704516
# iteration 1200 / 3000: loss 2.384927
# iteration 1300 / 3000: loss 2.204285
# iteration 1400 / 3000: loss 2.174888
# iteration 1500 / 3000: loss 2.025533
# iteration 1600 / 3000: loss 2.076060
# iteration 1700 / 3000: loss 2.071415
# iteration 1800 / 3000: loss 1.922855
# iteration 1900 / 3000: loss 2.055468
# iteration 2000 / 3000: loss 2.059660
# iteration 2100 / 3000: loss 2.048306
# iteration 2200 / 3000: loss 2.068806
# iteration 2300 / 3000: loss 2.083717
# iteration 2400 / 3000: loss 2.054424
# iteration 2500 / 3000: loss 2.016016
# iteration 2600 / 3000: loss 2.066404
# iteration 2700 / 3000: loss 2.085225
# iteration 2800 / 3000: loss 2.038411
# iteration 2900 / 3000: loss 2.023025
# iteration 0 / 3000: loss 772.294895
# iteration 100 / 3000: loss 283.289633
# iteration 200 / 3000: loss 104.925938
# iteration 300 / 3000: loss 39.749397
# iteration 400 / 3000: loss 15.878407
# iteration 500 / 3000: loss 7.138357
# iteration 600 / 3000: loss 3.971189
# iteration 700 / 3000: loss 2.810202
# iteration 800 / 3000: loss 2.367776
# iteration 900 / 3000: loss 2.054555
# iteration 1000 / 3000: loss 2.135958
# iteration 1100 / 3000: loss 2.121790
# iteration 1200 / 3000: loss 2.056546
# iteration 1300 / 3000: loss 2.002132
# iteration 1400 / 3000: loss 2.117356
# iteration 1500 / 3000: loss 2.083363
# iteration 1600 / 3000: loss 2.109827
# iteration 1700 / 3000: loss 2.080318
# iteration 1800 / 3000: loss 2.079420
# iteration 1900 / 3000: loss 2.091929
# iteration 2000 / 3000: loss 2.102862
# iteration 2100 / 3000: loss 2.106243
# iteration 2200 / 3000: loss 2.068600
# iteration 2300 / 3000: loss 2.011007
# iteration 2400 / 3000: loss 2.137041
# iteration 2500 / 3000: loss 2.146792
# iteration 2600 / 3000: loss 2.043802
# iteration 2700 / 3000: loss 2.089815
# iteration 2800 / 3000: loss 2.062027
# iteration 2900 / 3000: loss 2.107622
# iteration 0 / 3000: loss 1521.930862
# iteration 100 / 3000: loss 204.825298
# iteration 200 / 3000: loss 29.244938
# iteration 300 / 3000: loss 5.748283
# iteration 400 / 3000: loss 2.622158
# iteration 500 / 3000: loss 2.228005
# iteration 600 / 3000: loss 2.150436
# iteration 700 / 3000: loss 2.195707
# iteration 800 / 3000: loss 2.134727
# iteration 900 / 3000: loss 2.124206
# iteration 1000 / 3000: loss 2.151213
# iteration 1100 / 3000: loss 2.110158
# iteration 1200 / 3000: loss 2.132996
# iteration 1300 / 3000: loss 2.144684
# iteration 1400 / 3000: loss 2.140279
# iteration 1500 / 3000: loss 2.144079
# iteration 1600 / 3000: loss 2.118577
# iteration 1700 / 3000: loss 2.136899
# iteration 1800 / 3000: loss 2.179477
# iteration 1900 / 3000: loss 2.139596
# iteration 2000 / 3000: loss 2.121193
# iteration 2100 / 3000: loss 2.147841
# iteration 2200 / 3000: loss 2.131042
# iteration 2300 / 3000: loss 2.149824
# iteration 2400 / 3000: loss 2.134122
# iteration 2500 / 3000: loss 2.175055
# iteration 2600 / 3000: loss 2.174619
# iteration 2700 / 3000: loss 2.125384
# iteration 2800 / 3000: loss 2.138268
# iteration 2900 / 3000: loss 2.107183
# iteration 0 / 3000: loss 35.915007
# iteration 100 / 3000: loss 27.633301
# iteration 200 / 3000: loss 22.532491
# iteration 300 / 3000: loss 18.560538
# iteration 400 / 3000: loss 15.467418
# iteration 500 / 3000: loss 12.822307
# iteration 600 / 3000: loss 10.804608
# iteration 700 / 3000: loss 9.103799
# iteration 800 / 3000: loss 7.882756
# iteration 900 / 3000: loss 6.680546
# iteration 1000 / 3000: loss 5.695138
# iteration 1100 / 3000: loss 5.094247
# iteration 1200 / 3000: loss 4.419303
# iteration 1300 / 3000: loss 4.098098
# iteration 1400 / 3000: loss 3.606255
# iteration 1500 / 3000: loss 3.306674
# iteration 1600 / 3000: loss 3.001010
# iteration 1700 / 3000: loss 2.821543
# iteration 1800 / 3000: loss 2.557539
# iteration 1900 / 3000: loss 2.557184
# iteration 2000 / 3000: loss 2.424983
# iteration 2100 / 3000: loss 2.222089
# iteration 2200 / 3000: loss 2.252999
# iteration 2300 / 3000: loss 2.176573
# iteration 2400 / 3000: loss 2.068983
# iteration 2500 / 3000: loss 1.933178
# iteration 2600 / 3000: loss 1.991886
# iteration 2700 / 3000: loss 1.935356
# iteration 2800 / 3000: loss 1.957945
# iteration 2900 / 3000: loss 2.008281
# iteration 0 / 3000: loss 473.237553
# iteration 100 / 3000: loss 24.572358
# iteration 200 / 3000: loss 3.131190
# iteration 300 / 3000: loss 2.140511
# iteration 400 / 3000: loss 2.096866
# iteration 500 / 3000: loss 1.947186
# iteration 600 / 3000: loss 2.028578
# iteration 700 / 3000: loss 2.061772
# iteration 800 / 3000: loss 2.036557
# iteration 900 / 3000: loss 1.974508
# iteration 1000 / 3000: loss 2.065468
# iteration 1100 / 3000: loss 2.063861
# iteration 1200 / 3000: loss 1.992846
# iteration 1300 / 3000: loss 2.072499
# iteration 1400 / 3000: loss 2.000293
# iteration 1500 / 3000: loss 2.055623
# iteration 1600 / 3000: loss 2.040070
# iteration 1700 / 3000: loss 2.122047
# iteration 1800 / 3000: loss 2.040513
# iteration 1900 / 3000: loss 2.072662
# iteration 2000 / 3000: loss 2.081084
# iteration 2100 / 3000: loss 2.043556
# iteration 2200 / 3000: loss 2.076922
# iteration 2300 / 3000: loss 1.964489
# iteration 2400 / 3000: loss 2.006224
# iteration 2500 / 3000: loss 2.050025
# iteration 2600 / 3000: loss 2.006722
# iteration 2700 / 3000: loss 2.080445
# iteration 2800 / 3000: loss 2.059997
# iteration 2900 / 3000: loss 1.998113
# iteration 0 / 3000: loss 769.168197
# iteration 100 / 3000: loss 6.878747
# iteration 200 / 3000: loss 2.143885
# iteration 300 / 3000: loss 2.050758
# iteration 400 / 3000: loss 2.083760
# iteration 500 / 3000: loss 2.126478
# iteration 600 / 3000: loss 2.074819
# iteration 700 / 3000: loss 2.151352
# iteration 800 / 3000: loss 2.128499
# iteration 900 / 3000: loss 2.115481
# iteration 1000 / 3000: loss 2.070918
# iteration 1100 / 3000: loss 2.119661
# iteration 1200 / 3000: loss 2.122197
# iteration 1300 / 3000: loss 2.061200
# iteration 1400 / 3000: loss 2.084987
# iteration 1500 / 3000: loss 2.049228
# iteration 1600 / 3000: loss 2.122453
# iteration 1700 / 3000: loss 2.137320
# iteration 1800 / 3000: loss 2.114330
# iteration 1900 / 3000: loss 2.089133
# iteration 2000 / 3000: loss 2.084499
# iteration 2100 / 3000: loss 2.108196
# iteration 2200 / 3000: loss 2.060185
# iteration 2300 / 3000: loss 2.068044
# iteration 2400 / 3000: loss 2.111687
# iteration 2500 / 3000: loss 2.005411
# iteration 2600 / 3000: loss 2.095384
# iteration 2700 / 3000: loss 2.082224
# iteration 2800 / 3000: loss 2.041673
# iteration 2900 / 3000: loss 2.073509
# iteration 0 / 3000: loss 1534.863423
# iteration 100 / 3000: loss 2.191237
# iteration 200 / 3000: loss 2.148544
# iteration 300 / 3000: loss 2.181394
# iteration 400 / 3000: loss 2.162752
# iteration 500 / 3000: loss 2.167145
# iteration 600 / 3000: loss 2.165056
# iteration 700 / 3000: loss 2.165278
# iteration 800 / 3000: loss 2.141462
# iteration 900 / 3000: loss 2.128811
# iteration 1000 / 3000: loss 2.119283
# iteration 1100 / 3000: loss 2.099296
# iteration 1200 / 3000: loss 2.073746
# iteration 1300 / 3000: loss 2.120923
# iteration 1400 / 3000: loss 2.144258
# iteration 1500 / 3000: loss 2.159936
# iteration 1600 / 3000: loss 2.099290
# iteration 1700 / 3000: loss 2.141784
# iteration 1800 / 3000: loss 2.175114
# iteration 1900 / 3000: loss 2.165282
# iteration 2000 / 3000: loss 2.124824
# iteration 2100 / 3000: loss 2.147396
# iteration 2200 / 3000: loss 2.110205
# iteration 2300 / 3000: loss 2.118329
# iteration 2400 / 3000: loss 2.167066
# iteration 2500 / 3000: loss 2.195798
# iteration 2600 / 3000: loss 2.111896
# iteration 2700 / 3000: loss 2.163211
# iteration 2800 / 3000: loss 2.172132
# iteration 2900 / 3000: loss 2.154789
# lr 1.000000e-08 reg 1.000000e+03 train accuracy: 0.177673 val accuracy: 0.179000
# lr 1.000000e-08 reg 1.500000e+04 train accuracy: 0.227551 val accuracy: 0.230000
# lr 1.000000e-08 reg 2.500000e+04 train accuracy: 0.243469 val accuracy: 0.239000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.295163 val accuracy: 0.308000
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.319245 val accuracy: 0.316000
# lr 1.000000e-07 reg 1.500000e+04 train accuracy: 0.341061 val accuracy: 0.356000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.330429 val accuracy: 0.343000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.312959 val accuracy: 0.332000
# lr 5.000000e-07 reg 1.000000e+03 train accuracy: 0.404102 val accuracy: 0.406000
# lr 5.000000e-07 reg 1.500000e+04 train accuracy: 0.344735 val accuracy: 0.346000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.327673 val accuracy: 0.347000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.296755 val accuracy: 0.319000
# best validation accuracy achieved during cross-validation: 0.406000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.396000

# %% [markdown]
# **Inline Question** - *True or False*
#
# It's possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# *Your answer*:True
#
# *Your explanation*:If a new datapoint is correctly classified the SVM loss will remain the same. On the other hand unless everything is perfectly scoredi n the softmax, if any classes have a non-zero value there will be an additional loss penalty for any new datapoint.

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
